# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats
import json

# %%
with open('/Users/patrickburke/OneDrive_EmoryUniversity/Econ372/FinalProject/Bronx/Montefiore Medical Center/131740114_MMC_Standard_Charges.json') as mont:
    mont_data = json.load(mont)

# %%
df = pd.DataFrame.from_dict(mont_data, orient='index')

# %%
df.head()
# Out:
#                                                     0       \
# columns                                           Hospital
# index                                                    0
# data     [MMC, DRG, APR001, None, None, Liver Transplan...
#
#                                                     1       \
# columns                                           CODETYPE
# index                                                    1
# data     [MMC, DRG, APR002, None, None, Heart &/Or Lung...
#
#                                                     2       \
# columns                                          PROCEDURE
# index                                                    2
# data     [MMC, DRG, APR003, None, None, Bone Marrow Tra...
#
#                                                     3       \
# columns                                                CPT
# index                                                    3
# data     [MMC, DRG, APR004, None, None, Tracheostomy W ...
#
# ...

# %%
df = df.transpose()

# %%
df.head()
# Out:
#      columns index                                               data
# 0   Hospital     0  [MMC, DRG, APR001, None, None, Liver Transplan...
# 1   CODETYPE     1  [MMC, DRG, APR002, None, None, Heart &/Or Lung...
# 2  PROCEDURE     2  [MMC, DRG, APR003, None, None, Bone Marrow Tra...
# 3        CPT     3  [MMC, DRG, APR004, None, None, Tracheostomy W ...
# 4   REV_CODE     4  [MMC, DRG, APR005, None, None, Tracheostomy W ...

# %%
column_list = mont_data['columns']

# %%
column_list
# Out:
# ['Hospital',
#  'CODETYPE',
#  'PROCEDURE',
#  'CPT',
#  'REV_CODE',
#  'PROCEDURE_DESCRIPTION',
#  'PATIENT_TYPE',
#  'Gross Charges',
#  'Cash Price',
#  '1199 COMMERICAL',
#  'AETNA ASA',
#  'AETNA COMMERCIAL',
#  'AFFINITY CHILD HEALTH PLUS',
#  'AFFINITY MEDICAID',
#  'AGEWELL NY',
#  'CARE CONNECT',
#  'CENTERS PLAN',
#  'CIGNA HMO',
#  'CIGNA PPO',
#  'CIGNA SA',
#  'EMBLEM HEALTH SELECT CARE',
#  'EMPIRE BCBS HEALTHPLUS EP 1 & 2',
#  'EMPIRE EXCHANGE',
#  'EMPIRE HMO',
#  'EMPIRE INDEMNITY',
#  'EMPIRE MEDICARE MANAGED CARE',
#  'EMPIRE PPO',
#  'EMPIREBCBS HP CHP B',
#  'ESSENTIAL PLANS 1-2',
#  'ESSENTIAL PLANS EMBLEM',
#  'ESSENTIALS PLAN 3-4',
#  'FIDELIS CHP',
#  'FIDELIS EXCHANGE',
#  'FIDELIS MEDICAID',
#  'FIDELIS MEDICARE',
#  'GHI COMMERCIAL',
#  'HB CENTERLIGHT MEDICARE MANAGED CARE',
#  'HB FIDELIS ESSENTIAL 3-4',
#  'HB FIDELIS ESSENTIAL PLAN 1-2',
#  'HB MCR Affinity Essentials 1&2',
#  'HB OSCAR',
#  'HB WELLCARE CHP',
#  'HB WELLCARE MEDICAID',
# ...

# %%
df.head()
# Out:
#      columns index                                               data
# 0   Hospital     0  [MMC, DRG, APR001, None, None, Liver Transplan...
# 1   CODETYPE     1  [MMC, DRG, APR002, None, None, Heart &/Or Lung...
# 2  PROCEDURE     2  [MMC, DRG, APR003, None, None, Bone Marrow Tra...
# 3        CPT     3  [MMC, DRG, APR004, None, None, Tracheostomy W ...
# 4   REV_CODE     4  [MMC, DRG, APR005, None, None, Tracheostomy W ...

# %%
data_list = []
for row in df.iterrows():
    data_list.append(row[1].data)
df2 = pd.DataFrame(data_list, columns=column_list)

# %%
df2.head()
# Out:
#   Hospital CODETYPE PROCEDURE   CPT REV_CODE  \
# 0      MMC      DRG    APR001  None     None
# 1      MMC      DRG    APR002  None     None
# 2      MMC      DRG    APR003  None     None
# 3      MMC      DRG    APR004  None     None
# 4      MMC      DRG    APR005  None     None
#
#                                PROCEDURE_DESCRIPTION PATIENT_TYPE  \
# 0        Liver Transplant &/Or Intestinal Transplant           IP
# 1                         Heart &/Or Lung Transplant           IP
# 2                             Bone Marrow Transplant           IP
# 3  Tracheostomy W Mv 96+ Hours W Extensive Proced...           IP
# 4  Tracheostomy W Mv 96+ Hours W/O Extensive Proc...           IP
#
#   Gross Charges Cash Price 1199 COMMERICAL  ...      OXFORD ASO  \
# 0     759194.83  493476.64  Not Applicable  ...  Not Applicable
# 1     935625.08   608156.3  Not Applicable  ...  Not Applicable
# 2     469336.41  305068.67  Not Applicable  ...  Not Applicable
# ...

# %%
#df2.to_excel('/Users/patrickburke/OneDrive - Emory University/Econ372/Final Project/Bronx/Montefiore Medical Center/MontefioreRawFixed.xlsx')

# %%
#df2.to_csv('/Users/patrickburke/OneDrive - Emory University/Econ372/Final Project/Bronx/Montefiore Medical Center/MontefioreRawFixed.csv')
