# %%
# Script name: presby work
# Author: Patrick Burke
# Date Created: 4/30/2022
# --------------------------
# Notes: 
# ---------------------------

# Packages
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats
import json

# %%
presby = pd.read_csv('/Users/patrickburke/OneDrive - Emory University/Econ372/Final Project/Queens/New York-Presbyterian Queens/presbyqueens6_all_insurance.csv')

# %%
presby
# Out:
#    Code (CPT/DRG)                                        Description  \
# 0             291                   HEART FAILURE AND SHOCK WITH MCC
# 1             312                               SYNCOPE AND COLLAPSE
# 2             392  ESOPHAGITIS, GASTROENTERITIS AND MISCELLANEOUS...
# 3             640  MISCELLANEOUS DISORDERS OF NUTRITION, METABOLI...
# 4             690    KIDNEY AND URINARY TRACT INFECTIONS WITHOUT MCC
# 5             871  SEPTICEMIA OR SEVERE SEPSIS WITHOUT MV >96 HOU...
#
#    Rev Code Inpatient/Outpatient  Gross Charges  Discounted Cash Price  \
# 0  Multiple           Inpatient     85028.26240            85028.26240
# 1  Multiple           Inpatient     51507.87845            51507.87845
# 2  Multiple           Inpatient     43007.05910            43007.05910
# 3  Multiple           Inpatient     71151.30120            71151.30120
# 4  Multiple           Inpatient     46754.98788            46754.98788
# ...

# %%
DRG_list = [291, 312, 392, 690, 871]

# %%
presby = presby[presby['Code (CPT/DRG)'].isin(DRG_list)]

# %%
presby
# Out:
#    Code (CPT/DRG)                                        Description  \
# 0             291                   HEART FAILURE AND SHOCK WITH MCC
# 1             312                               SYNCOPE AND COLLAPSE
# 2             392  ESOPHAGITIS, GASTROENTERITIS AND MISCELLANEOUS...
# 4             690    KIDNEY AND URINARY TRACT INFECTIONS WITHOUT MCC
# 5             871  SEPTICEMIA OR SEVERE SEPSIS WITHOUT MV >96 HOU...
#
#    Rev Code Inpatient/Outpatient  Gross Charges  Discounted Cash Price  \
# 0  Multiple           Inpatient     85028.26240            85028.26240
# 1  Multiple           Inpatient     51507.87845            51507.87845
# 2  Multiple           Inpatient     43007.05910            43007.05910
# 4  Multiple           Inpatient     46754.98788            46754.98788
# 5  Multiple           Inpatient    116661.30690           116661.30690
#
#          Aetna        Cigna  Empire Blue Cross Blue Shield  Emblem Health  \
# ...

# %%
presby = presby[['Code (CPT/DRG)','Aetna','Emblem Health','United Health Group'\
                    ,'1199']]
presby = presby.set_index(['Code (CPT/DRG)'])

# %%
presby
# Out:
#                       Aetna  Emblem Health  United Health Group        1199
# Code (CPT/DRG)
# 291             22342.58207    31123.06736          32788.87795  16302.7282
# 312             14774.67759    20581.02704          21682.59239  10780.6498
# 392             13490.45916    18792.11936          19797.93640   9843.5932
# 690             13987.23501    19484.12480          20526.98028  10206.0760
# 871             32980.98411    45942.29024          48401.27516  24065.2588

# %%
presby = presby.mean(axis=1)

# %%
presby
# Out:
# Code (CPT/DRG)
# 291    25639.313895
# 312    16954.736705
# 392    15481.027030
# 690    16051.104022
# 871    37847.452077
# dtype: float64

# %%
#presby.to_excel('/Users/patrickburke/OneDrive - Emory University/Econ372/Final Project/Queens/New York-Presbyterian Queens/presbyAvg2.xlsx')
